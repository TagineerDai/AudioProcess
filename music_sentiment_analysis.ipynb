# %% [markdown]
# # Music Sentiment Analysis
#
# ### Ref
# <https://github.com/muchen2/DeepSent>
#
# ###  Prerequisite
# ```sh
# sudo pip2 install pydub werkzeug flask sklearn
# python app_main.py
# ```
# On desktop.
# ```
# ssh -i .ssh/id_rsa -N -f -L localhost:5000:localhost:5000 <HostName>
# ```
# Result is as follows:

# %%
from PIL import Image
class LoadImage(object):
    def __init__(self, space='RGB'):
        self.space = space
    def __call__(self, path_img):
        with open(path_img, 'rb') as f:
            with Image.open(f) as img:
                img = img.convert(self.space)
        return img
imageloader = LoadImage()
imageloader('sentiment_analysis.png')
# Out:
# <PIL.Image.Image image mode=RGB size=1185x584 at 0x7F804A91A6A0>

# %% [markdown]
# ### TODO
# 0. Python3 compatible.
# 1. Music genre classification.
# 2. Fine tune the model with local music.
